# %%
mike = [87,82,2]
maarten = [86,83,2]
laurens = [87,83,1]
elijah = [84,86,1]

#ties = 2
g = 10
h = 10

for i in range(g):
    for j in range(h):
        print(
            (i, g - 1 - i),(j, h - 1 - j),
            (mike[0] + i + (mike[2] + 10 - g) / 2) / 180, 
            (maarten[0] + g - 1 - i + (maarten[2] + 10 - g) / 2) / 180,
            (laurens[0] + j + (laurens[2] + 10 - h) / 2) / 180,
            (elijah[0] + h - 1 - j + (elijah[2] + 10 - h) / 2) / 180
            )
# Out:
# (0, 9) (0, 9) 0.4888888888888889 0.5333333333333333 0.4861111111111111 0.5194444444444445
# (0, 9) (1, 8) 0.4888888888888889 0.5333333333333333 0.49166666666666664 0.5138888888888888
# (0, 9) (2, 7) 0.4888888888888889 0.5333333333333333 0.49722222222222223 0.5083333333333333
# (0, 9) (3, 6) 0.4888888888888889 0.5333333333333333 0.5027777777777778 0.5027777777777778
# (0, 9) (4, 5) 0.4888888888888889 0.5333333333333333 0.5083333333333333 0.49722222222222223
# (0, 9) (5, 4) 0.4888888888888889 0.5333333333333333 0.5138888888888888 0.49166666666666664
# (0, 9) (6, 3) 0.4888888888888889 0.5333333333333333 0.5194444444444445 0.4861111111111111
# (0, 9) (7, 2) 0.4888888888888889 0.5333333333333333 0.525 0.48055555555555557
# (0, 9) (8, 1) 0.4888888888888889 0.5333333333333333 0.5305555555555556 0.475
# (0, 9) (9, 0) 0.4888888888888889 0.5333333333333333 0.5361111111111111 0.46944444444444444
# (1, 8) (0, 9) 0.49444444444444446 0.5277777777777778 0.4861111111111111 0.5194444444444445
# ...
